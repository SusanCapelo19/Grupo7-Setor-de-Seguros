# %%
# caminho para o arquivo csv
caminho_csv = "/Volumes/workspace/default/arquivos-nttdata/CSV - NTTDATA/sinistros.csv"

# %%
# lendo o arquivo csv em um dataframe com algumas opções avançadas
df_sinistros = spark.read\
    .format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .option("sep", ",")\
    .load(caminho_csv)
# visualizando o dataframe
display(df_seguros)

# %%
# ver os nomes das colunas
df_sinistros.columns

# %%
# alterando nome da coluna "quem_forma_beneficiados" para "corretor_seguros" 
df_sinistros = df_sinistros.withColumnRenamed("quem_forma_beneficiados", "corretor_seguros")

# visualizando o dataframe
display(df_sinistros)

# %%
# verificando os tipos de dados do dataframe
df_sinistros.printSchema()

# %% [markdown]
# Tratamento de Dados Nulos

# %%
# importando funções para a detecção de valores nulos
from pyspark.sql.functions import col, count, when

# %%
# Verficando se as colunas possuem dados nulos
contador_nulo = [
    count(when(col(c).isNull(), c)).alias(c)
    for c in df_sinistros.columns
]

display(df_sinistros.select(contador_nulo))
